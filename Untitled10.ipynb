# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/saishasri.txt")
df
# Out:
#    NAME            AGE    GENDER     SYMPTOMS(YES/NO)  BLOOD PRESSURE  TEMPERATURE    DATE           TIME  HOW MANY DAYS BLOOD  RESULT
# 0   1.vishnu        34    male            yes     ...
# 1   2.shalini       54    female          no      ...
# 2   3.sairam        34    male            yes     ...
# 3   4.saisri        67    female          no      ...
# 4   5.adithiya      52    male            yes     ...
# 5   6.saisha        18    female          no      ...
# 6   7.selva         45    male            yes     ...
# 7   8.sujitha       67    female          yes     ...
# 8   9.krishna       32    male            no      ...
# 9   10.karthika     23    female          no      ...
# 10  11.srikanth     34    male            yes     ...
# 11  12.velvizhi     56    feamle          no      ...
# 12  13.rajesh       78    male            yes     ...
# 13  14.ramya        45    female          no      ...
# 14  15.ragul        51     male           yes     ...
# 15  16.ranjini      45    female          no      ...
# 16  17.madhan       56    male            no      ...
# 17  18.soundhrya    34    female          yes     ...
# 18  19.vasanth      56    male            yes     ...
# 19  20.yasheka      20    female          no      ...
# 20  21.vishnu       34    male            yes     ...
# 21  22.shalini      54    female          no      ...
# 22  23.sairam       34    male            yes     ...
# 23  24.saisri       67    female          no      ...
# 24  25.adithiya     52     male           yes     ...
# 25  26.saisha       18     female         no      ...
# 26  27.selva        45     male           yes     ...
# 27  28.sujitha      67     female         yes     ...
# 28  29.krishna      32     male           no      ...
# 29  30.karthika     32     female         no      ...
# 30  31.srikanth     34     male           yes     ...
# 31  32.velvizhi     56     female         no      ...
# 32  33.rajesh       78     male           yes     ...
# 33  34.ramya        45     female         no      ...
# 34  35.ragul        51     male           yes     ...
# 35  36.ranjini      45     feamle         no      ...
# 36  37.madhan       56     male           no      ...
# 37  38.soundhrya    34     feamle         yes     ...
# 38  39.vasanth      56     male           yes     ...
# 39  40.yasheka      20     female         no      ...
# 40  41.vishal       41     male           yes     ...
# 41  42.gopika       31     female         no      ...
# 42  43.vijay        44     male           yes     ...
# 43  44.deepika      32     female         no      ...
# 44  45.prakesh      35     male           no      ...
# 45  46.kaviya       23     female         yes     ...
# 46  47.praba        13     male           yes     ...
# 47  48.lavnaya      83     female         no      ...
# 48  49.shankar      43     male           yes     ...
# 49  50.swetha       32     female         no      ...

# %%
# Out:
#   File "/tmp/ipython-input-3-2132383951.py", line 2
#     'A':[1,2,np.nan,4]
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
d = {
    'A': [1,2, np.nan,4],
    'B':[5, np.nan, np.nan,4],
    'C':[1,2,3,4]
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 3  4.0  4.0  4

# %%
df.dropna(axis = 1)
# Out:
#    C
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 3  4.0  4.0  4

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
df.fillna(value='filling value')
# Out:
#                A              B  C
# 0            1.0            5.0  1
# 1            2.0  filling value  2
# 2  filling value  filling value  3
# 3            4.0            4.0  4

# %%
df=pd.DataFrame(d)

# %%
a=df['A'].fillna(value=df['A'].mean())

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
a
# Out:
# 0    1.000000
# 1    2.000000
# 2    2.333333
# 3    4.000000
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.000000
# 1    2.000000
# 2    2.333333
# 3    4.000000
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
df.fillna
# Out:
# <bound method NDFrame.fillna of      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4>

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
data={
    'company':['google' ,'google','MSFT','MSFT','FB','FB','IBM'],
    'person':['sam','nihad','Any','van','rakib','ovi'],
    'sales':[200,300,124,340,243,350]
}

# %%
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-34-1923510999.py in <cell line: 0>()
# ----> 1 df = pd.DataFrame(data)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     501             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     502
# --> 503     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     504
#     505
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112         # figure out the index, if necessary
#     113         if index is None:
# --> 114             index = _extract_index(arrays)
#     115         else:
#     116             index = ensure_index(index)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     675         lengths = list(set(raw_lengths))
#     676         if len(lengths) > 1:
# --> 677             raise ValueError("All arrays must be of the same length")
#     678
#     679         if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4
